# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = fig.add_subplot(2, 3, 1)
ax2 = fig.add_subplot(2, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)
ax4 = fig.add_subplot(2, 3, 4)
ax5 = fig.add_subplot(2, 3, 5)

# %%
import numpy as np

fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3, fig=fig)
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2, fig=fig)
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2, fig=fig)
ax4 = plt.subplot2grid((3, 3), (2, 0), fig=fig)
ax4 = plt.subplot2grid((3, 3), (2, 1), fig=fig)

# %% [markdown]
# ### practice 1

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,7), facecolor='linen')
fig.add_subplot(311)
fig.add_subplot(312)
fig.add_subplot(313)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(3, 1, figsize=(7, 7), facecolor='linen')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = plt.subplot2grid((3, 1), (0, 0) ,fig=fig)
ax2 = plt.subplot2grid((3, 1), (1, 0), fig=fig)
ax3 = plt.subplot2grid((3, 1), (2, 0), fig=fig)

# %% [markdown]
# ### practice 2

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# %%
fig, axes = plt.subplots(2, 2, facecolor='linen', figsize=(7, 7))

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = plt.subplot2grid((2, 2), (0, 0), fig=fig)
ax2 = plt.subplot2grid((2, 2), (0, 1), fig=fig)
ax3 = plt.subplot2grid((2, 2), (1, 0), fig=fig)
ax4 = plt.subplot2grid((2, 2), (1, 1), fig=fig)

# %% [markdown]
# ### practice 3

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(224)

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = plt.subplot2grid((2, 2), (0, 0), rowspan=2, fig=fig)
ax2 = plt.subplot2grid((2, 2), (0, 1), fig=fig)
ax3 = plt.subplot2grid((2, 2), (1, 1), fig=fig)

# %% [markdown]
# ### practice 4

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(549)
ax3 = fig.add_subplot(5, 4, 10)
ax3 = fig.add_subplot(5,4, 11)
ax3 = fig.add_subplot(5,4,12)
ax3 = fig.add_subplot(5,4,13)
ax3 = fig.add_subplot(5,4,14)
ax3 = fig.add_subplot(5,4,15)
ax3 = fig.add_subplot(5,4,16)
ax3 = fig.add_subplot(5,4,17)
ax3 = fig.add_subplot(5,4,18)
ax3 = fig.add_subplot(5,4,19)
ax3 = fig.add_subplot(5,4,20)

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')
ax1 = plt.subplot2grid((5, 4), (0, 0), rowspan=2, colspan=2, fig=fig)
ax2 = plt.subplot2grid((5, 4), (0, 2), rowspan=2, colspan=2, fig=fig)

ax3 = plt.subplot2grid((5, 4), (2, 0),  fig=fig)
ax4 = plt.subplot2grid((5, 4), (2, 1),  fig=fig)
ax5 = plt.subplot2grid((5, 4), (2, 2),  fig=fig)
ax6 = plt.subplot2grid((5, 4), (2, 3),  fig=fig)
ax7 = plt.subplot2grid((5, 4), (3, 0),  fig=fig)
ax8 = plt.subplot2grid((5, 4), (3, 1),  fig=fig)
ax9 = plt.subplot2grid((5, 4), (3, 2),  fig=fig)
ax10 = plt.subplot2grid((5, 4), (3, 3),  fig=fig)
ax11 = plt.subplot2grid((5, 4), (4, 0),  fig=fig)
ax12 = plt.subplot2grid((5, 4), (4, 1),  fig=fig)
ax13 = plt.subplot2grid((5, 4), (4, 2),  fig=fig)
ax14 = plt.subplot2grid((5, 4), (4, 3),  fig=fig)

# %%
import numpy as np

fig = plt.figure(figsize=(7, 7), facecolor='linen')

axes = np.empty(shape=(0,))

axes = np.append(axes, plt.subplot2grid((5, 4), (0, 0), colspan=2, rowspan=2, fig=fig))
axes = np.append(axes, plt.subplot2grid((5, 4), (0, 2), colspan=2, rowspan=2, fig=fig))

for row in range(2, 5):
    for col in range(0, 4):
        axes = np.append(axes, plt.subplot2grid((5, 4), (row, col), fig=fig))

# %% [markdown]
# ### add_axes

# %%
import matplotlib.pyplot as plt
import numpy as np

left , bottom = 0.1, 0.1
spacing = 0.005

width1, height1 = 0.65, 0.65

width2, height2 = 1 - (2 * left + width1 + spacing), 1 - (2 * bottom + height1 + spacing)

rect1 = [left, bottom, width1, height1]
rect2 = [left + width1 + spacing, bottom, width2, height1]
rect3 = [left, bottom + height1 + spacing, width1, height2]

fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_axes(rect1)
ax2 = fig.add_axes(rect2)
ax3 = fig.add_axes(rect3)
